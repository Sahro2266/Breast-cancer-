# %% [markdown]
# # Project 1&2 - Breast Cancer Analysis and Visualization
#
# *Projects are an important part of the learning and assessment process in this course. Plan on committing considerable resources to each Project.*
#
# ## Writeup
# In the[ Project 1&2 Writeup ](https://docs.google.com/document/d/1zhQBpoNJCui3dMJiWbjlQ0fzuoQoF2vM2vV9CIdwvZs/edit?usp=sharing)include a description of each row you are removing and your justification for removing it.
#
# ## Background on Breast Cancer
#
#
# > Breast cancer is cancer that forms in the cells of the breasts. After skin cancer, breast cancer is the most common cancer diagnosed in women in the United States. Breast cancer can occur in both men and women, but it's far more common in women. -- [MayoClinic.org](https://www.mayoclinic.org/diseases-conditions/breast-cancer/symptoms-causes/syc-20352470)
#
# > A tumor can be **benign** (not dangerous to health) or **malignant** (has the potential to be dangerous). Benign tumors are not considered cancerous: their cells are close to normal in appearance, they grow slowly, and they do not invade nearby tissues or spread to other parts of the body. Malignant tumors are cancerous. Left unchecked, malignant cells eventually can spread beyond the original tumor to other parts of the body. -- [BreastCancer.org](https://www.breastcancer.org/symptoms/understand_bc/what_is_bc)
#
# ## Overview of the Data
#
# This data was originally obtained from the University of Wisconsin Hospitals, Madison from Dr. William H. Wolberg. This data has become a standard machine learning example and can be found both at the [University of California-Irvine Machine Learning Repository](http://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29) and the[ Kaggle Data sets](https://www.kaggle.com/uciml/breast-cancer-wisconsin-data). Both of these sites can provide additional details on the data.
#
# The dataset contains over 500 samples of malignant and benign tumor cells.
#
# - The first two columns in the dataset store the unique ID numbers of the samples and the corresponding diagnosis (M=malignant, B=benign), respectively.
# - The columns 3-32 contain 30 real-value features that have been computed from digitized images of the cell nuclei, which can be used to build a model to predict whether a tumor is benign or malignant.

# %% [markdown]
# # Section 0: Setup

# %% [markdown]
# ## Setting up Python tools:
#
# We'll use three libraries for this tutorial: [pandas](http://pandas.pydata.org/), [matplotlib](http://matplotlib.org/), and [seaborn](http://stanford.edu/~mwaskom/software/seaborn/).

# %%
# First, we'll import pandas, a data processing and CSV file I/O library
import pandas as pd

# We'll also import seaborn and matplot, twp Python graphing libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read in the Wisconsin Breast Cancer data
# The Breast Cancer data is read in from a file stored on the internet
# <p>
# It is stored in a Pandas DataFrame which is similar to an internal spreadsheet in that the data is stored in rows and columns.

# %%
# Read in the data file from stored in a raw file in GitHub
url = 'https://raw.githubusercontent.com/CIS3115-Machine-Learning-Scholastica/CIS3115ML-Units1and2/master/breast-cancer-wisconsin-mod.csv'
url = 'https://raw.githubusercontent.com/CIS3115-Machine-Learning-Scholastica/CIS3115ML-Units1and2/master/breast-cancer-wisconsin-mod.csv'
cancer = pd.read_csv(url)
# Set the Id column as the index since it is unique for each pati
cancer.set_index('id', inplace=True)

# %%
# Display the first 5 rows at the start, or head, of the dataframe
cancer.head(5)
# Out:
#       diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 8670  Malignant        15.46         19.48          101.70      748.9
# 8913     Benign        12.89         13.12           81.89      515.9
# 8915     Benign        14.96         19.10           97.03      687.3
# 5555     Benign          NaN           NaN             NaN        NaN
# 9047     Benign        12.94         16.17           83.18      507.6
#
#       smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# id
# 8670          0.10920           0.12230         0.14660              0.08087
# 8913          0.06955           0.03729         0.02260              0.01171
# 8915          0.08992           0.09823         0.05940              0.04819
# 5555              NaN               NaN         0.00000              0.00000
# 9047          0.09879           0.08836         0.03296              0.02390
#
#       symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# id                   ...
# 8670         0.1931  ...         19.26          26.00           124.90
# 8913         0.1337  ...         13.62          15.54            87.40
# 8915         0.1879  ...         16.25          26.19           109.10
# 5555         0.0000  ...           NaN            NaN              NaN
# 9047         0.1735  ...         13.86          23.02            89.69
#
#       area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# id
# 8670      1156.0           0.15460             0.2394           0.3791
# 8913       577.0           0.09616             0.1147           0.1186
# 8915       809.8           0.13130             0.3030           0.1804
# 5555         NaN               NaN             0.1958           0.1810
# 9047       580.9           0.11720             0.1958           0.1810
#
#       concave points_worst  symmetry_worst  fractal_dimension_worst
# id
# 8670               0.15140          0.2837                  0.08019
# 8913               0.05366          0.2309                  0.06915
# 8915               0.14890          0.2962                  0.08472
# 5555               0.08388          0.0000                  0.00000
# 9047               0.08388          0.3297                  0.07834
#
# [5 rows x 31 columns]

# %% [markdown]
# # Task 1: Clean up the Data
# There are a number of errors in this data. Looking back at the Practice 2 notebook, do the following:
# - Remove any rows with blank cells
# - Remove any rows with abnormal or erroneous data
#
# ---
#
# In the[ Project 1 Writeup ](https://docs.google.com/document/d/1zhQBpoNJCui3dMJiWbjlQ0fzuoQoF2vM2vV9CIdwvZs/edit?usp=sharing)include a description of each row you are removing and your justification for removing it.

# %%
cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 573 entries, 8670 to 911320502
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                573 non-null    object
#  1   radius_mean              571 non-null    float64
#  2   texture_mean             571 non-null    float64
#  3   perimeter_mean           571 non-null    float64
#  4   area_mean                571 non-null    float64
#  5   smoothness_mean          571 non-null    float64
#  6   compactness_mean         571 non-null    float64
#  7   concavity_mean           572 non-null    float64
#  8   concave points_mean      573 non-null    float64
#  9   symmetry_mean            573 non-null    float64
#  10  fractal_dimension_mean   573 non-null    float64
#  11  radius_se                573 non-null    float64
#  12  texture_se               573 non-null    float64
#  13  perimeter_se             573 non-null    float64
#  14  area_se                  572 non-null    float64
#  15  smoothness_se            573 non-null    float64
#  16  compactness_se           573 non-null    float64
#  17  concavity_se             573 non-null    float64
#  18  concave points_se        573 non-null    float64
#  19  symmetry_se              573 non-null    float64
#  20  fractal_dimension_se     573 non-null    float64
#  21  radius_worst             571 non-null    float64
#  22  texture_worst            571 non-null    float64
#  23  perimeter_worst          571 non-null    float64
#  24  area_worst               571 non-null    float64
#  25  smoothness_worst         571 non-null    float64
#  26  compactness_worst        572 non-null    float64
#  27  concavity_worst          573 non-null    float64
#  28  concave points_worst     573 non-null    float64
#  29  symmetry_worst           573 non-null    float64
#  30  fractal_dimension_worst  573 non-null    float64
# dtypes: float64(30), object(1)
# memory usage: 143.2+ KB

# %%
# include code in these cells for analyzing the data and removing the needed rows

# %%
cancer_clean = cancer.dropna()

# %%
cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 573 entries, 8670 to 911320502
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                573 non-null    object
#  1   radius_mean              571 non-null    float64
#  2   texture_mean             571 non-null    float64
#  3   perimeter_mean           571 non-null    float64
#  4   area_mean                571 non-null    float64
#  5   smoothness_mean          571 non-null    float64
#  6   compactness_mean         571 non-null    float64
#  7   concavity_mean           572 non-null    float64
#  8   concave points_mean      573 non-null    float64
#  9   symmetry_mean            573 non-null    float64
#  10  fractal_dimension_mean   573 non-null    float64
#  11  radius_se                573 non-null    float64
#  12  texture_se               573 non-null    float64
#  13  perimeter_se             573 non-null    float64
#  14  area_se                  572 non-null    float64
#  15  smoothness_se            573 non-null    float64
#  16  compactness_se           573 non-null    float64
#  17  concavity_se             573 non-null    float64
#  18  concave points_se        573 non-null    float64
#  19  symmetry_se              573 non-null    float64
#  20  fractal_dimension_se     573 non-null    float64
#  21  radius_worst             571 non-null    float64
#  22  texture_worst            571 non-null    float64
#  23  perimeter_worst          571 non-null    float64
#  24  area_worst               571 non-null    float64
#  25  smoothness_worst         571 non-null    float64
#  26  compactness_worst        572 non-null    float64
#  27  concavity_worst          573 non-null    float64
#  28  concave points_worst     573 non-null    float64
#  29  symmetry_worst           573 non-null    float64
#  30  fractal_dimension_worst  573 non-null    float64
# dtypes: float64(30), object(1)
# memory usage: 143.2+ KB

# %%
print("After removing NaN rows:", cancer_clean.shape)
# Out:
# After removing NaN rows: (571, 31)

# %%
print(cancer_clean['diagnosis'].value_counts())
# Out:
# diagnosis
# Benign       357
# Malignant    214
# Name: count, dtype: int64

# %%
cancer_clean = cancer_clean[cancer_clean['diagnosis'].isin(['Benign', 'Malignant'])]
print("After removing bad diagnosis rows:", cancer_clean.shape)
# Out:
# After removing bad diagnosis rows: (571, 31)

# %%
cancer_clean = cancer_clean[(cancer_clean.select_dtypes(include='float64') >= 0).all(axis=1)]
print("After removing negative value rows:", cancer_clean.shape)
# Out:
# After removing negative value rows: (570, 31)

# %% [markdown]
# # Task 2: Visualize the Data
# You must create five visualizations of the breast cancer data. For each visualization, include a description using full sentences of the following
# - What the visualization shows
# - Why this might be useful
# - Any external sources for the code you used--simple URLs are fine.
# - Something you would like to improve with the visualization
#
#  You can certainly reuse some of the visualizations from Practice 2, but here are some additional notebooks to look at for inspiration:
# - [Python ML - breast cancer diagnostic data set](https://www.kaggle.com/rcfreitas/python-ml-breast-cancer-diagnostic-data-set)
# - [ Breast Cancer Images](https://www.kaggle.com/reyhaneh/breast-cancer-image)
# - [ Data analysis using pandas and seaborn & sklearn](https://www.kaggle.com/akshaymewada7/data-analysis-using-pandas-and-seaborn-sklearn)
# - [Breast Cancer Risk Prediction ](https://github.com/Jean-njoroge/Breast-cancer-risk-prediction/blob/master/NB2_ExploratoryDataAnalysis.ipynb)
# - [Exploratory Analysis on Breast Cancer Data Set](https://www.inertia7.com/projects/3)

# %% [markdown]
# ### Visualization 0

# %%
# Code for Visualization 0
# We'll use seaborn's FacetGrid to color the scatterplot by species
sns.FacetGrid(cancer, hue="diagnosis") \
   .map(plt.scatter, "radius_mean", "texture_mean") \
   .add_legend()

# %% [markdown]
# ### Description of Visualization 1
#
# Describe your visualization in the [Project 1 Writeup ](https://docs.google.com/document/d/1zhQBpoNJCui3dMJiWbjlQ0fzuoQoF2vM2vV9CIdwvZs/edit?usp=sharing)

# %%
# Graphs using Matplotlib
# Creating the bar plot using Matplotlib


import matplotlib.pyplot as plt


plt.bar(cancer['diagnosis'], cancer['radius_mean'])


plt.title("Diagnosis vs Radius Mean")
plt.xlabel("Diagnosis")
plt.ylabel("Radius Mean")


plt.show()

# %% [markdown]
# ### Description of Visualization 2
#
# Describe your visualization in the [Project 1 Writeup ](https://docs.google.com/document/d/1zhQBpoNJCui3dMJiWbjlQ0fzuoQoF2vM2vV9CIdwvZs/edit?usp=sharing)

# %% [markdown]
# ### Description of Visualization 3
#
# Describe your visualization in the [Project 1 Writeup ](https://docs.google.com/document/d/1zhQBpoNJCui3dMJiWbjlQ0fzuoQoF2vM2vV9CIdwvZs/edit?usp=sharing)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set a clean style
sns.set_style("whitegrid")

# Create larger figure
plt.figure(figsize=(12, 7))

# Scatter plot with diagnosis as color
sns.scatterplot(
    data=cancer,
    x='radius_mean',
    y='texture_mean',
    hue='diagnosis',
    palette='Set1',
    s=80
)

# Add title and labels
plt.title("Relationship Between Radius Mean and Texture Mean", fontsize=16)
plt.xlabel("Radius Mean", fontsize=12)
plt.ylabel("Texture Mean", fontsize=12)

# Improve legend
plt.legend(title="Diagnosis")

# Show plot
plt.show()

# %% [markdown]
# ### Description of Visualization 4
#
# Describe your visualization in the [Project 1 Writeup ](https://docs.google.com/document/d/1zhQBpoNJCui3dMJiWbjlQ0fzuoQoF2vM2vV9CIdwvZs/edit?usp=sharing)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(15,8)})

sns.countplot(cancer['diagnosis'])

plt.xticks(rotation=70)

# plt.set_size_inches(15,15)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350., 400.]),
#  [Text(0.0, 0, '0'),
#   Text(50.0, 0, '50'),
#   Text(100.0, 0, '100'),
#   Text(150.0, 0, '150'),
#   Text(200.0, 0, '200'),
#   Text(250.0, 0, '250'),
#   Text(300.0, 0, '300'),
#   Text(350.0, 0, '350'),
#   Text(400.0, 0, '400')])

# %% [markdown]
# ### Description of Visualization 5
#
# Describe your visualization in the [Project 1 Writeup ](https://docs.google.com/document/d/1zhQBpoNJCui3dMJiWbjlQ0fzuoQoF2vM2vV9CIdwvZs/edit?usp=sharing)

# %%
cancer['diagnosis'].value_counts().plot.bar()


plt.xticks(rotation=70)
plt.title("Count of Cancer Diagnosis")
plt.xlabel("Diagnosis")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Wrapping Up
#
# Remember to share this notebook and the writeup with your instructor and submit a link to it in Blackboard.

# %%
# Access a single column using dot notation
display(cancer.radius_mean.head())

# Access a single column using bracket notation
display(cancer['radius_mean'].head())

# Access a range of rows and columns using integer-location based indexing (iloc)
# iloc[row_start:row_end, col_start:col_end]
display(cancer.iloc[ 0:5 , 1:3 ]) # Access rows 0 to 4 and columns 1 to 2

# Access all rows for a range of columns using iloc
display(cancer.iloc[ : , 1:3].head()) # Access all rows for columns 1 to 2

# Access a range of rows for all columns using iloc
display(cancer.iloc[ 0:5 ].head()) # Access rows 0 to 4 for all columns

# Access specific rows using a list of indices with iloc
display(cancer.iloc[ [0, 2, 4] ]) # Access rows with index 0, 2, and 4
# Out:
# id
# 8670    15.46
# 8913    12.89
# 8915    14.96
# 5555      NaN
# 9047    12.94
# Name: radius_mean, dtype: float64
# id
# 8670    15.46
# 8913    12.89
# 8915    14.96
# 5555      NaN
# 9047    12.94
# Name: radius_mean, dtype: float64
#       radius_mean  texture_mean
# id
# 8670        15.46         19.48
# 8913        12.89         13.12
# 8915        14.96         19.10
# 5555          NaN           NaN
# 9047        12.94         16.17
#       radius_mean  texture_mean
# id
# 8670        15.46         19.48
# 8913        12.89         13.12
# 8915        14.96         19.10
# 5555          NaN           NaN
# 9047        12.94         16.17
#       diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 8670  Malignant        15.46         19.48          101.70      748.9
# 8913     Benign        12.89         13.12           81.89      515.9
# 8915     Benign        14.96         19.10           97.03      687.3
# 5555     Benign          NaN           NaN             NaN        NaN
# 9047     Benign        12.94         16.17           83.18      507.6
#
#       smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# id
# 8670          0.10920           0.12230         0.14660              0.08087
# 8913          0.06955           0.03729         0.02260              0.01171
# 8915          0.08992           0.09823         0.05940              0.04819
# 5555              NaN               NaN         0.00000              0.00000
# 9047          0.09879           0.08836         0.03296              0.02390
#
#       symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# id                   ...
# 8670         0.1931  ...         19.26          26.00           124.90
# 8913         0.1337  ...         13.62          15.54            87.40
# 8915         0.1879  ...         16.25          26.19           109.10
# 5555         0.0000  ...           NaN            NaN              NaN
# 9047         0.1735  ...         13.86          23.02            89.69
#
#       area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# id
# 8670      1156.0           0.15460             0.2394           0.3791
# 8913       577.0           0.09616             0.1147           0.1186
# 8915       809.8           0.13130             0.3030           0.1804
# 5555         NaN               NaN             0.1958           0.1810
# 9047       580.9           0.11720             0.1958           0.1810
#
#       concave points_worst  symmetry_worst  fractal_dimension_worst
# id
# 8670               0.15140          0.2837                  0.08019
# 8913               0.05366          0.2309                  0.06915
# 8915               0.14890          0.2962                  0.08472
# 5555               0.08388          0.0000                  0.00000
# 9047               0.08388          0.3297                  0.07834
#
# [5 rows x 31 columns]
#       diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 8670  Malignant        15.46         19.48          101.70      748.9
# 8915     Benign        14.96         19.10           97.03      687.3
# 9047     Benign        12.94         16.17           83.18      507.6
#
#       smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# id
# 8670          0.10920           0.12230         0.14660              0.08087
# 8915          0.08992           0.09823         0.05940              0.04819
# 9047          0.09879           0.08836         0.03296              0.02390
#
#       symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# id                   ...
# 8670         0.1931  ...         19.26          26.00           124.90
# 8915         0.1879  ...         16.25          26.19           109.10
# 9047         0.1735  ...         13.86          23.02            89.69
#
#       area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# id
# 8670      1156.0            0.1546             0.2394           0.3791
# 8915       809.8            0.1313             0.3030           0.1804
# 9047       580.9            0.1172             0.1958           0.1810
#
#       concave points_worst  symmetry_worst  fractal_dimension_worst
# id
# 8670               0.15140          0.2837                  0.08019
# 8915               0.14890          0.2962                  0.08472
# 9047               0.08388          0.3297                  0.07834
#
# [3 rows x 31 columns]
